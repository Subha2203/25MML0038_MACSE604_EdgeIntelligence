# %%
# !pip install nltk
# Out:
# Collecting nltk
#   Downloading nltk-3.9.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting click (from nltk)
#   Downloading click-8.1.8-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: joblib in c:\users\hsubh\anaconda3\envs\ml_lab\lib\site-packages (from nltk) (1.4.2)
# Collecting regex>=2021.8.3 (from nltk)
#   Downloading regex-2025.11.3-cp39-cp39-win_amd64.whl.metadata (41 kB)
# Requirement already satisfied: tqdm in c:\users\hsubh\anaconda3\envs\ml_lab\lib\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: colorama in c:\users\hsubh\anaconda3\envs\ml_lab\lib\site-packages (from click->nltk) (0.4.6)
# Downloading nltk-3.9.2-py3-none-any.whl (1.5 MB)
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 1.5/1.5 MB 11.5 MB/s eta 0:00:00
# Downloading regex-2025.11.3-cp39-cp39-win_amd64.whl (277 kB)
# Downloading click-8.1.8-py3-none-any.whl (98 kB)
# Installing collected packages: regex, click, nltk
#
#    ------------- -------------------------- 1/3 [click]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    ---------------------------------------- 3/3 [nltk]
#
# Successfully installed click-8.1.8 nltk-3.9.2 regex-2025.11.3

# %%
import nltk
nltk.download('names')
# Out:
# [nltk_data] Downloading package names to
# [nltk_data]     C:\Users\hsubh\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\names.zip.
# True

# %%
from nltk.corpus import names
names.words()
print(len(names.words()))
# Out:
# 7944

# %%
def gender_features(word):
    return {'last_letter':word[-1]}

# %%
labeled_names=([(name,'male') for name in names.words("male.txt")]+[ (name,'female') for name in names.words("female.txt")])

# %%
import random 
random.shuffle(labeled_names)
featuresets=[(gender_features(n),gender) for (n,gender)in labeled_names ]

# %%
import random
random.shuffle(labeled_names)
featuresets = [(gender_features(n), gender) for (n,gender) in labeled_names]
train_set, test_set = featuresets[5000:], featuresets[:2000]
import nltk
classifier= nltk.NaiveBayesClassifier.train(train_set)
classifier.classify(gender_features('David'))
classifier.classify(gender_features('Yann Lecun'))

print(nltk.classify.accuracy(classifier,test_set))
# Out:
# 0.7535

# %%
import pandas as pd
data = pd.read_csv(r"D:\VIT\Sem 2\Edge Intelligence\LAB 2\logs_dataset.csv")
print(data.head())
# Out:
#                     @timestamp                   _id  ip_address
# 0  July 8th 2019, 14:43:03.000  XswJ0msBoTGddM7vxMDB  10.1.1.285
# 1  July 8th 2019, 14:43:01.000  dKQJ0msB7mP0GwVzvJjz  10.1.2.389
# 2  July 8th 2019, 14:42:59.000  CcwJ0msBoTGddM7vtb8y  10.1.1.415
# 3  July 8th 2019, 14:42:57.000  bKQJ0msB7mP0GwVzrZdT   10.1.1.79
# 4  July 8th 2019, 14:42:55.000  L6QJ0msB7mP0GwVzpZeI   10.1.1.60

# %%
len(data)
# Out:
# 721547
